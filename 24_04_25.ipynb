# %% [markdown]
# <a href="https://colab.research.google.com/github/SaulPichardo/python_THC/blob/main/24_04_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Librería **Pandas**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

link='https://github.com/mike1502/HerramientasComputacionales/blob/main/Pandas/ebola_2014_2016_clean.csv'
code='?raw=true' #para que pandas lea el archivo csv
url=link+code #se unen el link y el codigo para leer el archivo
df=pd.read_csv(url,sep=',',index_col=1)

df.head() #visualizar el encabezado del dataframe (base de datos), por defecto muestra las primeras 5 filas y el encabezado
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 29/08/2014        Guinea                     482                    287.0
# 29/08/2014       Nigeria                      15                      6.0
# 29/08/2014  Sierra Leone                     935                    380.0
# 29/08/2014       Liberia                     322                    225.0
# 05/09/2014        Guinea                     604                    362.0
# 05/09/2014       Liberia                     614                    431.0
# 05/09/2014       Nigeria                      18                      7.0
# 05/09/2014       Senegal                       1                      0.0
# 05/09/2014  Sierra Leone                    1146                    443.0
# 08/09/2014       Nigeria                      19                      7.0
#
#             Male Cases  Female Cases    Boys   Girls  Adult Male  \
# Date
# 29/08/2014       289.2         192.8   86.76   57.84      173.52
# ...

# %%
df.tail() #visualiza las ultimas filas del dataframe
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 23/03/2016                   Liberia                    3151
# 23/03/2016                     Italy                       1
# 23/03/2016                   Liberia                       2
# 23/03/2016                   Nigeria                      19
# 23/03/2016  United States of America                       4
#
#             No. of confirmed deaths  Male Cases  Female Cases    Boys   Girls  \
# Date
# 23/03/2016                      NaN      1890.6        1260.4  567.18  378.12
# 23/03/2016                      NaN         0.6           0.4    0.18    0.12
# 23/03/2016                      1.0         1.2           0.8    0.36    0.24
# 23/03/2016                      7.0        11.4           7.6    3.42    2.28
# 23/03/2016                      1.0         2.4           1.6    0.72    0.48
#
#             Adult Male  Adult Female  Old Male  Old Female
# Date
# ...

# %%
df.info() #informacion y tipo de dato por columna
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2484 entries, 29/08/2014 to 23/03/2016
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  2484 non-null   object
#  1   No. of confirmed cases   2484 non-null   int64
#  2   No. of confirmed deaths  1648 non-null   float64
#  3   Male Cases               2484 non-null   float64
#  4   Female Cases             2484 non-null   float64
#  5   Boys                     2484 non-null   float64
#  6   Girls                    2484 non-null   float64
#  7   Adult Male               2484 non-null   float64
#  8   Adult Female             2484 non-null   float64
#  9   Old Male                 2484 non-null   float64
#  10  Old Female               2484 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 297.4+ KB

# %%
df.describe() #visualizar las estadisticas de cada columna
# Out:
#        No. of confirmed cases  No. of confirmed deaths   Male Cases  \
# count             2484.000000              1648.000000  2484.000000
# mean              1436.616345               781.662015   861.969807
# std               2574.200797              1258.113098  1544.520478
# min                  1.000000                 0.000000     0.600000
# 25%                  1.000000                 0.000000     0.600000
# 50%                  7.000000                 2.000000     4.200000
# 75%               3118.000000              1760.750000  1870.800000
# max               8704.000000              3858.000000  5222.400000
#
#        Female Cases         Boys        Girls   Adult Male  Adult Female  \
# count   2484.000000  2484.000000  2484.000000  2484.000000   2484.000000
# mean     574.646538   258.590942   172.393961   517.181884    344.787923
# std     1029.680319   463.356143   308.904096   926.712287    617.808191
# ...

# %%
df['Country'].isin(['Mexico']).sum()
#consulto en el df, en la columna de pais, si existe informacion sobre el ebola en mexico
# Out:
# np.int64(0)

# %%
df.isnull().sum()
#entro a la base de datos para buscar datos nulos y sumarlos
# Out:
# Country                      0
# No. of confirmed cases       0
# No. of confirmed deaths    836
# Male Cases                   0
# Female Cases                 0
# Boys                         0
# Girls                        0
# Adult Male                   0
# Adult Female                 0
# Old Male                     0
# Old Female                   0
# dtype: int64

# %%
promedio_muertos=df['No. of confirmed deaths'].mean()
df['No. of confirmed deaths'].fillna(promedio_muertos, inplace=True) #promediar los casos de muertes confirmadas y reemplazar los valores vacios con ese. alor.
# Out:
# <ipython-input-21-7b815de54047>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['No. of confirmed deaths'].fillna(promedio_muertos, inplace=True)

# %%
df.tail(10)
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 23/03/2016              Sierra Leone                    8704
# 23/03/2016                   Senegal                       1
# 23/03/2016                      Mali                       7
# 23/03/2016            United Kingdom                       1
# 23/03/2016                   Liberia                       9
# 23/03/2016                   Liberia                    3151
# 23/03/2016                     Italy                       1
# 23/03/2016                   Liberia                       2
# 23/03/2016                   Nigeria                      19
# 23/03/2016  United States of America                       4
#
#             No. of confirmed deaths  Male Cases  Female Cases     Boys  \
# Date
# 23/03/2016              3589.000000      5222.4        3481.6  1566.72
# 23/03/2016                 0.000000         0.6           0.4     0.18
# ...

# %%
df.isnull().sum()
# Out:
# Country                    0
# No. of confirmed cases     0
# No. of confirmed deaths    0
# Male Cases                 0
# Female Cases               0
# Boys                       0
# Girls                      0
# Adult Male                 0
# Adult Female               0
# Old Male                   0
# Old Female                 0
# dtype: int64

# %%
#vamos a contar los casos por pais
conteo=df.groupby('Country').size().reset_index(name='conteo')
conteo=conteo.sort_values(by='conteo',ascending=False)
conteo
# Out:
#                     Country  conteo
# 2                   Liberia     364
# 0                    Guinea     259
# 6              Sierra Leone     259
# 4                   Nigeria     255
# 5                   Senegal     254
# 9  United States of America     245
# 7                     Spain     243
# 3                      Mali     243
# 8            United Kingdom     221
# 1                     Italy     141

# %%
data_missing=df['No. of confirmed deaths'].isnull().groupby(df['Country']).sum()
data_missing=data_missing.sort_values(ascending=False)
data_missing
# Out:
# Country
# Guinea                      0
# Italy                       0
# Liberia                     0
# Mali                        0
# Nigeria                     0
# Senegal                     0
# Sierra Leone                0
# Spain                       0
# United Kingdom              0
# United States of America    0
# Name: No. of confirmed deaths, dtype: int64

# %%
plt.pie(conteo['conteo'],labels=conteo['Country'],autopct='%1.1f%%')
plt.axis('equal')
plt.title('Casos de Ebola por País')
plt.savefig('Casos de Ebola por País',dpi=300,format='png')
plt.show()

# %%
Senegal=df[df['Country']=='Senegal']
Senegal.head()
# Out:
#             Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 05/09/2014  Senegal                       1                      0.0
# 08/09/2014  Senegal                       1                      0.0
# 12/09/2014  Senegal                       1                      0.0
# 16/09/2014  Senegal                       1                      0.0
# 18/09/2014  Senegal                       1                      0.0
#
#             Male Cases  Female Cases  Boys  Girls  Adult Male  Adult Female  \
# Date
# 05/09/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 08/09/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 12/09/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 16/09/2014         0.6           0.4  0.18   0.12        0.36          0.24
# 18/09/2014         0.6           0.4  0.18   0.12        0.36          0.24
#
#             Old Male  Old Female
# Date
# 05/09/2014      0.06        0.04
# ...

# %%
Senegal.isnull().sum() #comprobamos que no hay valores nulos
# Out:
# Country                    0
# No. of confirmed cases     0
# No. of confirmed deaths    0
# Male Cases                 0
# Female Cases               0
# Boys                       0
# Girls                      0
# Adult Male                 0
# Adult Female               0
# Old Male                   0
# Old Female                 0
# dtype: int64

# %%
Senegal.shape #cuantas filas y cuantas columnas hay
# Out:
# (254, 11)

# %%
Senegal_infectados=Senegal['No. of confirmed cases'][0:-1:10] #asignamos variable de infectados
Senegal_muertos=Senegal['No. of confirmed deaths'][0:-1:10] #asignamos variable para las muertes
fechas=Senegal.index[0:-1:10] #extraemos las fechas para el rango propuesto
plt.figure(figsize=(10,5))
plt.plot(fechas,Senegal_infectados,'o:r', ms=3, label='infectados')
plt.plot(fechas,Senegal_muertos, ms=3, label='muertos')
plt.grid() #malla de la grafica
plt.legend()
plt.xticks(rotation=90,fontsize=8)
plt.savefig('Casos de Ebola en Senegal',dpi=300,format='png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Liberia=df[df['Country']=='Liberia']
Liberia.head()
# Out:
#             Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 29/08/2014  Liberia                     322                    225.0
# 05/09/2014  Liberia                     614                    431.0
# 08/09/2014  Liberia                     634                    508.0
# 12/09/2014  Liberia                     654                    498.0
# 16/09/2014  Liberia                     790                    563.0
#
#             Male Cases  Female Cases    Boys  Girls  Adult Male  Adult Female  \
# Date
# 29/08/2014       193.2         128.8   57.96  38.64      115.92         77.28
# 05/09/2014       368.4         245.6  110.52  73.68      221.04        147.36
# 08/09/2014       380.4         253.6  114.12  76.08      228.24        152.16
# 12/09/2014       392.4         261.6  117.72  78.48      235.44        156.96
# 16/09/2014       474.0         316.0  142.20  94.80      284.40        189.60
#
#             Old Male  Old Female
# Date
# ...

# %%
Liberia.isnull().sum()
# Out:
# Country                    0
# No. of confirmed cases     0
# No. of confirmed deaths    0
# Male Cases                 0
# Female Cases               0
# Boys                       0
# Girls                      0
# Adult Male                 0
# Adult Female               0
# Old Male                   0
# Old Female                 0
# dtype: int64

# %%
Liberia_hombres=Liberia['Male Cases'][0:-1:10]
Liberia_mujeres=Liberia['Female Cases'][0:-1:10]
fechas=Liberia.index[0:-1:10]
plt.figure(figsize=(10,5))
plt.plot(fechas,Liberia_hombres,'o:r', ms=3, label='hombres')
plt.plot(fechas,Liberia_mujeres, ms=3, label='mujeres')
plt.grid()
plt.legend()
plt.xticks(rotation=90,fontsize=8)
plt.savefig('Generos en casos de Ebola en Liberia',dpi=300,format='png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
MC=Liberia['Male Cases'][0:-1:10]
B=Liberia['Boys'][0:-1:10]
AM=Liberia['Adult Male'][0:-1:10]
OM=Liberia['Old Male'][0:-1:10]

fechas=Liberia.index[0:-1:10]

plt.figure(figsize=(10,5))
plt.bar(fechas,MC,color='blue',label='Total', alpha=0.6)
plt.bar(fechas,B,color='yellow', label='Niños', alpha=0.6)
plt.bar(fechas,AM,color='pink' label='Adultos', alpha=0.6)
plt.bar(fechas,OM,color='red',label='Adulto Mayor', alpha=0.6)
# Out:
#   File "<ipython-input-52-2bb21d5ce0b9>", line 11
#     plt.bar(fechas,AM,color='pink' label='Adultos', alpha=0.6)
#                             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
